# %%
from app.indexing.github_parsing import GitHubParser

# %%
url = 'https://github.com/soddencarpenter/agentic-rag'

parser = GitHubParser("")

parser.parse_url(url)

# %%
url = 'https://github.com/huggenface/transformers/tree/run_run_all_tests'
parser = GitHubParser("")

parser.parse_url(url)

# %%
url = 'https://github.com/soddencarpenter/agentic-rag'
parser = GitHubParser(url)

eles = parser.parse_repo()
len(eles)

# %%
url = 'https://github.com/huggingface/transformers/tree/run_run_all_tests'
parser = GitHubParser(url)

eles = parser.parse_repo()
len(eles)
# Out:
# 7318

# %%
print(eles[-1])
# Out:
# text='def get_all_model_names():\n    model_names = set()\n    # Each auto modeling files contains multiple mappings. Let\'s get them in a dynamic way.\n    for module_name in ["modeling_auto", "modeling_tf_auto", "modeling_flax_auto"]:\n        module = getattr(transformers.models.auto, module_name, None)\n        if module is None:\n            continue\n        # all mappings in a single auto modeling file\n        mapping_names = [\n            x\n            for x in dir(module)\n            if x.endswith("_MAPPING_NAMES")\n            and (x.startswith("MODEL_") or x.startswith("TF_MODEL_") or x.startswith("FLAX_MODEL_"))\n        ]\n        for name in mapping_names:\n            mapping = getattr(module, name)\n            if mapping is not None:\n                for v in mapping.values():\n                    if isinstance(v, (list, tuple)):\n                        model_names.update(v)\n                    elif isinstance(v, str):\n                        model_names.add(v
# ...
